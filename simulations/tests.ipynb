# %%
import numpy as np
import matplotlib.pyplot as plt

# Camera resolution
cam_width = 1440
cam_height = 1080

# Create the grid
x = np.arange(cam_width)
y = np.arange(cam_height)
X, Y = np.meshgrid(x, y)

# Mean photon count per pixel (can be non-uniform for more realism)
mean_photon_counts = np.random.uniform(0, 0.5, (cam_height, cam_width))

# Generate the photon counts using a Poisson distribution
intensity_grid = np.random.poisson(mean_photon_counts)

# Visualize the intensity grid
plt.figure(figsize=(8, 6))
plt.imshow(intensity_grid, cmap="hot")
plt.colorbar(label="Photon Count")
plt.title("Photon Emission with Poisson Noise")
plt.axis("off")
plt.show()

# %%
# Visualize the intensity grid
plt.figure(figsize=(8, 6))
plt.imshow(intensity_grid[0:100, 0:100], cmap="hot")
plt.colorbar(label="Photon Count")
plt.title("Photon Emission with Poisson Noise")
plt.axis("off")
plt.show()
